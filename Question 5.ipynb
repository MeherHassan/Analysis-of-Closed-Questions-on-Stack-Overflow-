# %%
import pandas as pd
df = pd.read_csv('posts.csv')
df.head(50)
# Out:
# C:\Users\RAMBO\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     Unnamed: 0    Id  PostTypeId  AcceptedAnswerId  ParentId  \
# 0            0    72           1              -999      -999
# 1            1    85           1               154      -999
# 2            2    90           1           1466832      -999
# 3            3   108           1               111      -999
# 4            4   126           1               127      -999
# 5            5   129           1              -999      -999
# 6            6   180           1               539      -999
# 7            7   337           1               342      -999
# 8            8   470           1               473      -999
# 9            9   549           1            477578      -999
# ...

# %%
r =df['Tags'].value_counts(normalize=True)*100

# %%
dfd = pd.DataFrame(r)

# %%
dfd.head(20)
# Out:
#                                 Tags
# <java>                      1.884432
# <php>                       1.585870
# <javascript>                1.491989
# <python>                    1.300954
# <c#>                        1.048650
# <c++>                       1.031047
# <javascript><jquery>        0.821181
# <php><mysql>                0.810265
# <android>                   0.766736
# <c>                         0.713519
# <html><css>                 0.648430
# <r>                         0.578702
# <java><android>             0.386165
# <jquery>                    0.328036
# <python><python-3.x>        0.307022
# <javascript><html>          0.305930
# <javascript><jquery><html>  0.288873
# <mysql>                     0.286281
# <php><html>                 0.227469
# <css>                       0.214506

# %%
import matplotlib.pyplot as plt

data = [1.884432,1.585870, 1.491989, 1.300954, 1.048650,
       1.031047, 0.821181,0.810265 , 0.766736, 0.713519,
       0.648430 , 0.578702, 0.386165,0.328036 ,0.307022,
       0.305930, 0.288873, 0.286281,0.227469 , 0.214506]
labels = ['java', 'php', 'javascript', 'pythonD', 'c#',
         'c++','javascript jquery','php mysql','android','c',
         'html css','r','java android','jquery','python python-3.x',
         'javascript html','javascript jquery html','mysql','php html','css']
plt.xticks(range(len(data)), labels)
#plt.xlabel('Class')
plt.ylabel('Normalized Ratio Of Tags')
plt.bar(range(len(data)), data) 

plt.xticks(rotation=90)
plt.show()
