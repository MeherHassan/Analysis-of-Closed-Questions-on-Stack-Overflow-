# %%
import pandas as pd
df1 = pd.read_csv('PostHistory.csv')

df1.head(5)
# Out:
#    Unnamed: 0   Id  PostHistoryTypeId  PostId  \
# 0           0  334                  1      85
# 1           1  335                  3      85
# 2           2  336                  2      85
# 3           3  337                  6      85
# 4           4  348                  1     337
#
#                            RevisionGUID             CreationDate  UserId  \
# 0  b318af61-cf87-485f-ab67-e0143863d43c  2008-08-01T14:19:52.510      59
# 1  b318af61-cf87-485f-ab67-e0143863d43c  2008-08-01T14:19:52.510      59
# 2  b318af61-cf87-485f-ab67-e0143863d43c  2008-08-01T14:19:52.510      59
# 3  4c7b0e66-3117-4701-b11b-2e83746ca394  2008-08-02T02:37:08.373      59
# 4  236db042-c4e2-49cc-b00f-72e7f6745e13  2008-08-02T03:35:55.697     111
#
#   UserDisplayName Comment                                               Text
# 0             NaN     NaN                         Flat File Databases in PHP
# 1             NaN     NaN                                              <php>
# ...

# %%
df2 = pd.read_csv('posts.csv')
# Out:
# C:\Users\RAMBO\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
dfinal = df2.merge(df1, on="Id")
dfinal.head(5)
# Out:
#    Unnamed: 0_x     Id  PostTypeId  AcceptedAnswerId  ParentId  \
# 0             7    337           1               342      -999
# 1            88   5606           1              5752      -999
# 2           161  10880           1             10890      -999
# 3           173  12023           1             12024      -999
# 4           180  12556           1             16222      -999
#
#             CreationDate_x                                               Body  \
# 0  2008-08-02T03:35:55.697  <p>I am about to build a piece of a project th...
# 1  2008-08-08T03:03:46.520  <p>Pretty much all my career, I worked with bu...
# 2  2008-08-14T10:42:59.627  <p>I'm looking for a good article on using ema...
# 3  2008-08-15T06:28:20.650  <p>How do I attract developers to an open sour...
# 4  2008-08-15T18:00:04.020  <p>It looks interesting and I've played around...
#
#    OwnerUserId OwnerDisplayName  \
# 0          111              NaN
# 1          463              NaN
# ...

# %%
rslt_df = dfinal[dfinal['PostHistoryTypeId'] == 10]
rslt_df.head(5)
# Out:
#      Unnamed: 0_x       Id  PostTypeId  AcceptedAnswerId  ParentId  \
# 334         12459  1260516           1           1260546      -999
# 335         12461  1260680           1           1260700      -999
# 336         12467  1262020           1           1262030      -999
# 337         12469  1262174           1           1262184      -999
# 395         16081  1746996           1           1747307      -999
#
#               CreationDate_x  \
# 334  2009-08-11T13:51:55.287
# 335  2009-08-11T14:20:47.837
# 336  2009-08-11T18:05:27.497
# 337  2009-08-11T18:34:45.660
# 395  2009-11-17T06:36:49.950
#
#                                                   Body  OwnerUserId  \
# 334  <p>If I want to sell a web application as an i...       131050
# 335  <p>Is there a FREE (or relatively cheaper) Jav...       115622
# 336  <p>I'm implementing a class-like structure in ...        86937
# 337  <blockquote>\n  <p><strong>Possible Duplicate:...        89818
# ...

# %%
rst = rslt_df.drop(['Unnamed: 0_x','PostTypeId','AcceptedAnswerId','ParentId','CreationDate_x','OwnerUserId','OwnerDisplayName',
             'CommunityOwnedDate','Unnamed: 0_y','PostId','RevisionGUID','CreationDate_y','UserId','UserDisplayName','AnswerCount'
             ,'FavoriteCount','Text'], axis = 1)

# %%
rst.head(5)
# Out:
#           Id                                               Body  \
# 334  1260516  <p>If I want to sell a web application as an i...
# 335  1260680  <p>Is there a FREE (or relatively cheaper) Jav...
# 336  1262020  <p>I'm implementing a class-like structure in ...
# 337  1262174  <blockquote>\n  <p><strong>Possible Duplicate:...
# 395  1746996  <p>I'm looking for a library (or command line ...
#
#                                                  Title  \
# 334                         Licensing web applications
# 335                 Is there a FREE Java GUI designer?
# 336  How can I maintain control of the this keyword...
# 337  MySQL: Why use VARCHAR(20) instead of VARCHAR(...
# 395         Convert Microsoft Office documents to Text
#
#                                                  Tags  CommentCount  \
# 334  <web-applications><licensing><piracy-prevention>             2
# 335          <java><swing><open-source><gui-designer>             2
# ...

# %%
rst['Tags'].value_counts(ascending=True)
# Out:
# <mysql><sql><sql-server><oracle><oracle11g>                                   1
# <uitableview><image-processing><calayer><grand-central-dispatch><nscache>     1
# <excel><list><excel-formula>                                                  1
# <java><integer><int>                                                          1
# <android><google-maps><google-maps-api-3><markerclusterer>                    1
#                                                                              ..
# <c#>                                                                         35
# <php>                                                                        40
# <javascript>                                                                 54
# <python>                                                                     57
# <java>                                                                       65
# Name: Tags, Length: 2244, dtype: int64

# %%
final = rst.groupby('Comment')['Tags'].nunique()

# %%
final= pd.DataFrame(final)

# %%
final
# Out:
#          Tags
# Comment
# 1         730
# 101       194
# 102       240
# 103        83
# 104        26
# 105        50
# 2         214
# 3         315
# 4         508
# 7         218

# %%
import matplotlib.pyplot as plt
 
value1 = [1,730]
value2=[1,194]
value3=[1,240]
value4=[1,83]
value5=[1,26]
value6=[1,50]
value7=[1,214]
value8=[1,315]
value9=[1,508]
value10=[1,218]
box_plot_data=[value1,value2,value3,value4,value5,value6,value7,value8,value9,value10]
plt.boxplot(box_plot_data,patch_artist=True,labels=['ED','Dup','OT','Un',

          'Tb','POB','OT','SUB'
           ,'Nq','Tl'])

plt.xticks(rotation=90)

plt.ylabel('Number OF Tags')
plt.show()

# %%
rst.head(5)
# Out:
#           Id                                               Body  \
# 334  1260516  <p>If I want to sell a web application as an i...
# 335  1260680  <p>Is there a FREE (or relatively cheaper) Jav...
# 336  1262020  <p>I'm implementing a class-like structure in ...
# 337  1262174  <blockquote>\n  <p><strong>Possible Duplicate:...
# 395  1746996  <p>I'm looking for a library (or command line ...
#
#                                                  Title  \
# 334                         Licensing web applications
# 335                 Is there a FREE Java GUI designer?
# 336  How can I maintain control of the this keyword...
# 337  MySQL: Why use VARCHAR(20) instead of VARCHAR(...
# 395         Convert Microsoft Office documents to Text
#
#                                                  Tags  CommentCount  \
# 334  <web-applications><licensing><piracy-prevention>             2
# 335          <java><swing><open-source><gui-designer>             2
# ...

# %%
rst['Title_Count'] = rst['Title'].str.len()

# %%
rst.head(5)
# Out:
#           Id                                               Body  \
# 334  1260516  <p>If I want to sell a web application as an i...
# 335  1260680  <p>Is there a FREE (or relatively cheaper) Jav...
# 336  1262020  <p>I'm implementing a class-like structure in ...
# 337  1262174  <blockquote>\n  <p><strong>Possible Duplicate:...
# 395  1746996  <p>I'm looking for a library (or command line ...
#
#                                                  Title  \
# 334                         Licensing web applications
# 335                 Is there a FREE Java GUI designer?
# 336  How can I maintain control of the this keyword...
# 337  MySQL: Why use VARCHAR(20) instead of VARCHAR(...
# 395         Convert Microsoft Office documents to Text
#
#                                                  Tags  CommentCount  \
# 334  <web-applications><licensing><piracy-prevention>             2
# 335          <java><swing><open-source><gui-designer>             2
# ...

# %%
df = rst[['Comment','Title_Count']]
df.head(5)
# Out:
#     Comment  Title_Count
# 334       1           26
# 335       2           34
# 336       1           83
# 337       1           51
# 395       1           42

# %%
df.boxplot(column=['Title_Count' ], by = ['Comment'])
# Out:
# <AxesSubplot:title={'center':'Title_Count'}, xlabel='[Comment]'>

# %%
rst['Title_Count'].min()
# Out:
# 15

# %%
x=rst.groupby(['Comment','Title_Count'])['Title_Count'].count()

y=rst.groupby(['Comment'])['Title_Count'].count()
r=((x/y)*100).round(2)

dff = pd.DataFrame(r)
#df.head(120)
pd.set_option('display.max_rows', dff.shape[0]+1)
dff
# Out:
#                      Title_Count
# Comment Title_Count
# 1       15                  0.22
#         17                  0.44
#         18                  0.56
#         19                  0.33
#         20                  0.44
#         21                  0.56
#         22                  1.11
#         23                  1.44
#         24                  1.44
#         25                  1.33
#         26                  1.00
#         27                  1.44
#         28                  1.33
#         29                  1.33
#         30                  1.89
#         31                  1.67
#         32                  2.44
#         33                  1.56
#         34                  2.00
#         35                  3.22
#         36                  3.00
#         37                  1.78
#         38                  1.44
#         39                  3.00
#         40                  2.33
#         41                  2.44
# ...

# %%
import matplotlib.pyplot as plt
 
value1 = [15,149]
value2=[15,131]
value3=[15,134]
value4=[18,125]
value5=[25,140]
value6=[23,114]
value7=[15,127]
value8=[15,140]
value9=[16,145]
value10=[15,118]
box_plot_data=[value1,value2,value3,value4,value5,value6,value7,value8,value9,value10]
plt.boxplot(box_plot_data,patch_artist=True,labels=['Exact Duplicate','Duplicate','Off-topic','Unclear what youre asking',
                                                    'Too broad','Primarily opinion-based','Off-topic','Subjective and argumentative'
                                                   ,'Not a real question','Too localized'])

plt.xticks(rotation=90)

plt.ylabel('Number Of Title Length')
plt.show()

# %%
rst['Body_Count'] = rst['Body'].str.len()

# %%
rst.head(5)
# Out:
#           Id                                               Body  \
# 334  1260516  <p>If I want to sell a web application as an i...
# 335  1260680  <p>Is there a FREE (or relatively cheaper) Jav...
# 336  1262020  <p>I'm implementing a class-like structure in ...
# 337  1262174  <blockquote>\n  <p><strong>Possible Duplicate:...
# 395  1746996  <p>I'm looking for a library (or command line ...
#
#                                                  Title  \
# 334                         Licensing web applications
# 335                 Is there a FREE Java GUI designer?
# 336  How can I maintain control of the this keyword...
# 337  MySQL: Why use VARCHAR(20) instead of VARCHAR(...
# 395         Convert Microsoft Office documents to Text
#
#                                                  Tags  CommentCount  \
# 334  <web-applications><licensing><piracy-prevention>             2
# 335          <java><swing><open-source><gui-designer>             2
# ...

# %%
df = rst[['Comment','Body_Count']]
df.head(5)
# Out:
#     Comment  Body_Count
# 334       1         201
# 335       2          75
# 336       1         903
# 337       1         864
# 395       1         352

# %%
df.boxplot(column=['Body_Count' ], by = ['Comment'])
# Out:
# <AxesSubplot:title={'center':'Body_Count'}, xlabel='[Comment]'>

# %%
x=rst.groupby(['Comment','Body_Count'])['Body_Count'].count()

y=rst.groupby(['Comment'])['Body_Count'].count()
r=((x/y)*100).round(2)

dff = pd.DataFrame(r)
#df.head(120)
pd.set_option('display.max_rows', dff.shape[0]+1)
dff
# Out:
#                     Body_Count
# Comment Body_Count
# 1       25                0.11
#         73                0.11
#         75                0.11
#         76                0.11
#         91                0.11
#         101               0.11
#         107               0.11
#         108               0.11
#         109               0.11
#         111               0.11
#         115               0.11
#         125               0.22
#         130               0.11
#         136               0.11
#         143               0.11
#         147               0.11
#         148               0.22
#         149               0.22
#         150               0.11
#         151               0.11
#         152               0.11
#         155               0.11
#         156               0.11
#         159               0.11
#         160               0.11
#         161               0.11
#         162               0.11
#         164               0.33
# ...

# %%
import matplotlib.pyplot as plt
 
value1 = [25,31898]
value2=[126,7779]
value3=[43,15373]
value4=[119,14221]
value5=[354,4516]
value6=[137,9881]
value7=[70,11590]
value8=[80,19566]
value9=[81,18609]
value10=[95,8377]
box_plot_data=[value1,value2,value3,value4,value5,value6,value7,value8,value9,value10]
plt.boxplot(box_plot_data,patch_artist=True,labels=['Exact Duplicate','Duplicate','Off-topic','Unclear what youre asking',
                                                    'Too broad','Primarily opinion-based','Off-topic','Subjective and argumentative'
                                                   ,'Not a real question','Too localized'])

plt.xticks(rotation=90)

plt.ylabel('Number Of Body Length')
plt.show()

# %%
rslt_df = rst.loc[rst['Body'].str.contains("</code>", case=False)]

# %%
rslt_df.head(5)
# Out:
#            Id                                               Body  \
# 336   1262020  <p>I'm implementing a class-like structure in ...
# 639   3580419  <p>I have an excel spreadsheet with products a...
# 795   4728530  <p>Okay, I have given up on figuring this out....
# 1028  6427735  <p>I ve followed all the procedure that app st...
# 1030  6434558  <blockquote>\n  <p><strong>Possible Duplicate:...
#
#                                                   Title  \
# 336   How can I maintain control of the this keyword...
# 639                        Fastest way to populate a Db
# 795       PHP Call to a member function on a non-object
# 1028                  Invalid Code Signing Entitlements
# 1030         GreaseMonkey script to rewrite image links
#
#                                                    Tags  CommentCount  \
# 336          <jquery><prototype><oop><this><javascript>             5
# 639             <sql><mysql><database><database-design>             0
# ...

# %%
x=rslt_df.groupby(['Comment','Body'])['Body'].count()

y=rslt_df.groupby(['Comment'])['Body'].count()
r=((x/y)*100).round(2)

dff = pd.DataFrame(r)
#df.head(120)
pd.set_option('display.max_rows', dff.shape[0]+1)
#dff

# %%
rslt_df['Comment'].value_counts(normalize=True).sort_index(ascending=True)*100
# Out:
# 1      28.101710
# 101     8.461201
# 102     9.644893
# 103     3.068829
# 104     1.052170
# 105     1.928979
# 2       7.496712
# 3      12.275318
# 4      19.333626
# 7       8.636563
# Name: Comment, dtype: float64

# %%
import matplotlib.pyplot as plt

data = [28.101710,8.461201,9.644893,3.068829,1.052170,1.928979,7.496712,12.275318,19.333626,8.636563]
labels = ['ED','Dup','OT','Un',

          'Tb','POB','OT','SUB'
           ,'Nq','Tl']
plt.xticks(range(len(data)), labels)
#plt.xlabel('Class')
plt.ylabel('Percentage of Snippet Codes')
plt.bar(range(len(data)), data) 

plt.xticks(rotation=90)
plt.show()
