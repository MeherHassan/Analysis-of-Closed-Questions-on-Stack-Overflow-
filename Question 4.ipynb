# %%
import pandas as pd
df = pd.read_csv('Votes.csv')
df.head(10)
# Out:
#    Unnamed: 0    Id  PostId  VoteTypeId  UserId             CreationDate  \
# 0           0   128      85           2    -999  2008-08-01T00:00:00.000
# 1           1   195     126           2    -999  2008-08-01T00:00:00.000
# 2           2   211     126           2    -999  2008-08-01T00:00:00.000
# 3           3   224     108           2    -999  2008-08-01T00:00:00.000
# 4           4   304     180           2    -999  2008-08-01T00:00:00.000
# 5           5   531     126           3    -999  2008-08-02T00:00:00.000
# 6           6   666     337           2    -999  2008-08-02T00:00:00.000
# 7           7  1091     470           2    -999  2008-08-02T00:00:00.000
# 8           8  1104     126           2    -999  2008-08-02T00:00:00.000
# 9           9  1362     549           2    -999  2008-08-02T00:00:00.000
#
#    BountyAmount
# 0          -999
# 1          -999
# 2          -999
# 3          -999
# 4          -999
# 5          -999
# 6          -999
# 7          -999
# ...

# %%
import datetime as dt 

df['CreationDate'] = pd.to_datetime(df['CreationDate'])
df['MonthYear'] = df['CreationDate'].dt.to_period('M')
df.head(2)
# Out:
#    Unnamed: 0   Id  PostId  VoteTypeId  UserId CreationDate  BountyAmount  \
# 0           0  128      85           2    -999   2008-08-01          -999
# 1           1  195     126           2    -999   2008-08-01          -999
#
#   MonthYear
# 0   2008-08
# 1   2008-08

# %%
x=df.groupby(['MonthYear','VoteTypeId'])['VoteTypeId'].count()

y=df.groupby(['MonthYear'])['VoteTypeId'].count()
r=((x/y)*100).round(2)

dff = pd.DataFrame(r)
#df.head(120)
pd.set_option('display.max_rows', dff.shape[0]+1)
dff
# Out:
#                       VoteTypeId
# MonthYear VoteTypeId
# 2008-08   2                93.07
#           3                 6.93
# 2008-09   2                92.51
#           3                 7.49
# 2008-10   2                65.10
#           3                 3.78
#           5                31.12
# 2008-11   2                62.18
#           3                 3.63
#           5                34.18
# 2008-12   2                60.39
#           3                 3.98
#           5                35.63
# 2009-01   2                60.95
#           3                 3.94
#           5                35.01
#           8                 0.10
# 2009-02   2                60.35
#           3                 4.52
#           5                34.92
#           8                 0.21
# 2009-03   2                59.77
#           3                 4.12
#           5                35.82
#           8                 0.19
#           9                 0.03
# ...

# %%
 y=['2008-08','2008-09','2008-10','2008-11','2008-12','2009-01','2009-02','2009-03','2009-04','2009-05','2009-06'
  ,'2009-07','2009-08','2009-09','2009-10','2009-11','2009-12'
  ,'20010-01','20010-02','20010-03','20010-04','20010-05','20010-06'
  ,'20010-07','20010-08']
x2 = [93.07, 92.51, 65.10, 62.18, 60.39,
     60.95,60.35,59.77,58.68,59.40,59.05,58.37,58.38,57.67,56.39,58.56,58.48,
      4.60, 66.12, 67.33, 68.30, 65.98, 64.20, 64.62, 62.90] 
x3 = [6.93,7.49,3.78,3.63,3.98,
      3.94,4.52,4.12,4.36,3.37,3.82,3.72,3.38,3.32,3.30,3.86,3.52,
      4.60,4.31,3.33,2.54,3.53,5.27,5.48,5.97] 
x5 = [0,0,31.12,34.18,35.63,
      35.01,34.92,35.82,36.70,37.01,36.92,37.59,38.09,38.81,40.16,37.29,37.69,
     30.67,29.39, 29.22,28.98  ,30.19, 30.15 ,29.56,30.79 ]
x8 = [0,0,0,0,0,
    0.10,0.21,0.19,0.20,0.20,0.14,0.19,0.14,0.18,0.15,0.16,0.21,
     0.13, 0.10 ,0.12  ,0.12 , 0.10,0.16, 0.22,0.22 ]

# %%
import matplotlib.pyplot as plt
plt.plot(y,x2, label = "2 votes", linestyle="-") 
plt.plot(y,x3, label = "3 votes", linestyle=":")
plt.plot(y,x5, label = "5 votes", linestyle="dashed") 
plt.plot(y,x8, label = "8 votes", linestyle="-") 
plt.ylabel('Percentage of Closed Questions')
plt.xlabel('From 2010-01 to 2012-08')
plt.xticks(rotation=90)
plt.legend()
plt.show()
